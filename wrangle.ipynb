# %% [markdown]
# # Acquire
#
# **Goal: Your goal is to predict the values of single unit properties using the obervations from 2017.**
#
# **import**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import sys
from sklearn.model_selection import train_test_split

sys.path.append("./util_")
import acquire_
import prepare_

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **get data**

# %%
# sql query
query = """
SELECT *
FROM properties_2017 AS prop
INNER JOIN predictions_2017 USING(parcelid)
LEFT OUTER JOIN airconditioningtype USING(airconditioningtypeid)
LEFT OUTER JOIN architecturalstyletype USING(architecturalstyletypeid)
LEFT OUTER JOIN buildingclasstype USING(buildingclasstypeid)
LEFT OUTER JOIN heatingorsystemtype USING(heatingorsystemtypeid)
LEFT OUTER JOIN propertylandusetype USING(propertylandusetypeid)
LEFT OUTER JOIN storytype USING(storytypeid)
LEFT OUTER JOIN typeconstructiontype USING(typeconstructiontypeid)
WHERE latitude IS NOT NULL AND longitude IS NOT NULL;
"""

# %%
# get data from codeup database
zillow, q = acquire_.get_codeup_sql_data_(db_name="zillow", query=query,fileName="zillow_single_family")

# %% [markdown]
# ## Understand data

# %%
zillow.shape
# Out:
# (77580, 69)

# %%
zillow.columns
# Out:
# Index(['typeconstructiontypeid', 'storytypeid', 'propertylandusetypeid',
#        'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'parcelid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'id', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %%
zillow.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77580 entries, 0 to 77579
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        223 non-null    float64
#  1   storytypeid                   50 non-null     float64
#  2   propertylandusetypeid         77580 non-null  float64
#  3   heatingorsystemtypeid         49572 non-null  float64
#  4   buildingclasstypeid           15 non-null     float64
#  5   architecturalstyletypeid      207 non-null    float64
#  6   airconditioningtypeid         25007 non-null  float64
#  7   parcelid                      77580 non-null  int64
#  8   id                            77580 non-null  int64
#  9   basementsqft                  50 non-null     float64
#  10  bathroomcnt                   77580 non-null  float64
#  11  bedroomcnt                    77580 non-null  float64
#  12  buildingqualitytypeid         49810 non-null  float64
#  13  calculatedbathnbr             76964 non-null  float64
#  14  decktypeid                    614 non-null    float64
#  15  finishedfloor1squarefeet      6037 non-null   float64
#  16  calculatedfinishedsquarefeet  77379 non-null  float64
#  17  finishedsquarefeet12          73924 non-null  float64
#  18  finishedsquarefeet13          42 non-null     float64
#  19  finishedsquarefeet15          3027 non-null   float64
#  20  finishedsquarefeet50          6037 non-null   float64
#  21  finishedsquarefeet6           386 non-null    float64
#  22  fips                          77580 non-null  float64
#  23  fireplacecnt                  8289 non-null   float64
#  24  fullbathcnt                   76964 non-null  float64
#  25  garagecarcnt                  25520 non-null  float64
#  26  garagetotalsqft               25520 non-null  float64
#  27  hashottuborspa                1539 non-null   float64
#  28  latitude                      77580 non-null  float64
#  29  longitude                     77580 non-null  float64
#  30  lotsizesquarefeet             69322 non-null  float64
#  31  poolcnt                       16174 non-null  float64
#  32  poolsizesum                   869 non-null    float64
#  33  pooltypeid10                  465 non-null    float64
#  34  pooltypeid2                   1074 non-null   float64
#  35  pooltypeid7                   15079 non-null  float64
#  36  propertycountylandusecode     77580 non-null  object
#  37  propertyzoningdesc            50477 non-null  object
#  38  rawcensustractandblock        77580 non-null  float64
#  39  regionidcity                  76108 non-null  float64
#  40  regionidcounty                77580 non-null  float64
#  41  regionidneighborhood          30974 non-null  float64
#  42  regionidzip                   77530 non-null  float64
#  43  roomcnt                       77580 non-null  float64
#  44  threequarterbathnbr           10106 non-null  float64
#  45  unitcnt                       50704 non-null  float64
#  46  yardbuildingsqft17            2393 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77310 non-null  float64
#  49  numberofstories               17599 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77465 non-null  float64
#  52  taxvaluedollarcnt             77579 non-null  float64
#  53  assessmentyear                77580 non-null  float64
#  54  landtaxvaluedollarcnt         77578 non-null  float64
#  55  taxamount                     77575 non-null  float64
#  56  taxdelinquencyflag            2900 non-null   object
#  57  taxdelinquencyyear            2900 non-null   float64
#  58  censustractandblock           77333 non-null  float64
#  59  id                            77580 non-null  int64
#  60  logerror                      77580 non-null  float64
#  61  transactiondate               77580 non-null  object
#  62  airconditioningdesc           25007 non-null  object
#  63  architecturalstyledesc        207 non-null    object
#  64  buildingclassdesc             15 non-null     object
#  65  heatingorsystemdesc           49572 non-null  object
#  66  propertylandusedesc           77580 non-null  object
#  67  storydesc                     50 non-null     object
#  68  typeconstructiondesc          223 non-null    object
# dtypes: float64(55), int64(3), object(11)
# memory usage: 40.8+ MB

# %%
zillow.describe()
# Out:
#        typeconstructiontypeid          storytypeid  propertylandusetypeid  \
# count                  223.00                50.00              77,580.00
# mean                     6.04                 7.00                 261.82
# std                      0.56                 0.00                   5.14
# min                      4.00                 7.00                  31.00
# 25%                      6.00                 7.00                 261.00
# 50%                      6.00                 7.00                 261.00
# 75%                      6.00                 7.00                 266.00
# max                     13.00                 7.00                 275.00
#
#        heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# count              49,572.00                15.00                    207.00
# mean                    3.92                 3.93                      7.39
# std                     3.59                 0.26                      2.73
# min                     1.00                 3.00                      2.00
# 25%                     2.00                 4.00                      7.00
# 50%                     2.00                 4.00                      7.00
# 75%                     7.00                 4.00                      7.00
# max                    24.00                 4.00                     21.00
#
#        airconditioningtypeid             parcelid                   id  \
# count              25,007.00            77,580.00            77,580.00
# mean                    1.81        13,008,279.03         1,495,403.96
# std                     2.97         3,519,375.97           860,970.00
# min                     1.00        10,711,855.00               349.00
# 25%                     1.00        11,538,203.50           752,143.00
# 50%                     1.00        12,530,558.50         1,498,256.00
# 75%                     1.00        14,211,351.25         2,240,950.50
# max                    13.00       167,689,317.00         2,982,274.00
#
#               basementsqft  ...        fireplaceflag  \
# count                50.00  ...               172.00
# mean                679.72  ...                 1.00
# std                 689.70  ...                 0.00
# min                  38.00  ...                 1.00
# 25%                 273.00  ...                 1.00
# 50%                 515.00  ...                 1.00
# 75%                 796.50  ...                 1.00
# max               3,560.00  ...                 1.00
#
#        structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# count                   77,465.00            77,579.00            77,580.00
# mean                   189,279.64           490,147.61             2,016.00
# std                    230,409.55           653,794.17                 0.00
# min                         44.00             1,000.00             2,016.00
# 25%                     84,171.00           206,899.00             2,016.00
# 50%                    136,402.00           358,878.00             2,016.00
# 75%                    218,734.00           569,000.00             2,016.00
# max                 11,421,790.00        49,061,236.00             2,016.00
#
#        landtaxvaluedollarcnt            taxamount   taxdelinquencyyear  \
# count              77,578.00            77,575.00             2,900.00
# mean              301,150.00             5,995.93                14.09
# std               492,721.93             7,628.82                 2.18
# min                   161.00                19.92                 3.00
# 25%                85,293.25             2,712.65                14.00
# 50%               203,181.00             4,448.23                15.00
# 75%               366,739.75             6,926.89                15.00
# max            48,952,198.00           586,639.30                99.00
#
#          censustractandblock                   id             logerror
# count              77,333.00            77,580.00            77,580.00
# mean   60,496,672,300,497.99            38,806.72                 0.02
# std     1,533,329,446,287.88            22,403.76                 0.17
# min    60,371,011,101,000.00                 0.00                -4.66
# 25%    60,373,109,004,005.00            19,404.75                -0.02
# 50%    60,376,032,001,021.00            38,804.50                 0.01
# 75%    60,590,423,251,007.00            58,208.25                 0.04
# max   483,030,105,084,015.00            77,613.00                 5.26
#
# [8 rows x 58 columns]

# %%
# count of numeric columns and object columns
numerics = len(zillow.select_dtypes("number").columns)
objects = len(zillow.select_dtypes("object").columns)

print("Numeric col count:", numerics)
print("object col count:", objects)
# Out:
# Numeric col count: 58
# object col count: 11

# %% [markdown]
# Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
# create a dataframe from all the null counts
zillow_null_status = pd.DataFrame(zillow.isna().sum(axis=0))
zillow_null_status = zillow_null_status.rename(columns={0:"num_rows_missing"})

# add percentage of th missing values to the new data frame
zillow_null_status["pct_rows_missing"] = zillow_null_status.num_rows_missing / zillow.shape[0]
zillow_null_status.head()
# Out:
#                         num_rows_missing     pct_rows_missing
# typeconstructiontypeid             77357                 1.00
# storytypeid                        77530                 1.00
# propertylandusetypeid                  0                 0.00
# heatingorsystemtypeid              28008                 0.36
# buildingclasstypeid                77565                 1.00

# %% [markdown]
# **What I see:**
#
# - I have 2152863 rows and 7 columns
# - 7 of the 29 columns are numric while 0 of them are string object colums
# - I have unsure null values in my data
# - I also see the descriptive statistics of my data

# %% [markdown]
# # Prepare

# %%
zillow.T
# Out:
#                                             0                          1      \
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                         NaN                        NaN
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                          None                       None
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                             2                          3      \
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                         NaN                       2.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                          None                    Central
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                       4                    5      \
# typeconstructiontypeid                  NaN                  NaN
# storytypeid                             NaN                  NaN
# propertylandusetypeid                266.00               266.00
# heatingorsystemtypeid                  2.00                  NaN
# buildingclasstypeid                     NaN                  NaN
# ...                                     ...                  ...
# buildingclassdesc                      None                 None
# heatingorsystemdesc                 Central                 None
# propertylandusedesc             Condominium          Condominium
# storydesc                              None                 None
# typeconstructiondesc                   None                 None
#
#                                             6                          7      \
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                        NaN
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                       None
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                             8                    9      ...  \
# typeconstructiontypeid                        NaN                  NaN  ...
# storytypeid                                   NaN                  NaN  ...
# propertylandusetypeid                      261.00               266.00  ...
# heatingorsystemtypeid                        2.00                 2.00  ...
# buildingclasstypeid                           NaN                  NaN  ...
# ...                                           ...                  ...  ...
# buildingclassdesc                            None                 None  ...
# heatingorsystemdesc                       Central              Central  ...
# propertylandusedesc     Single Family Residential          Condominium  ...
# storydesc                                    None                 None  ...
# typeconstructiondesc                         None                 None  ...
#
#                                       77570                77571  \
# typeconstructiontypeid                  NaN                  NaN
# storytypeid                             NaN                  NaN
# propertylandusetypeid                266.00               266.00
# heatingorsystemtypeid                  2.00                 2.00
# buildingclasstypeid                     NaN                  NaN
# ...                                     ...                  ...
# buildingclassdesc                      None                 None
# heatingorsystemdesc                 Central              Central
# propertylandusedesc             Condominium          Condominium
# storydesc                              None                 None
# typeconstructiondesc                   None                 None
#
#                                             77572                      77573  \
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                       2.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                    Central
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                       77574                      77575  \
# typeconstructiontypeid                  NaN                        NaN
# storytypeid                             NaN                        NaN
# propertylandusetypeid                266.00                     261.00
# heatingorsystemtypeid                  2.00                       2.00
# buildingclasstypeid                     NaN                        NaN
# ...                                     ...                        ...
# buildingclassdesc                      None                       None
# heatingorsystemdesc                 Central                    Central
# propertylandusedesc             Condominium  Single Family Residential
# storydesc                              None                       None
# typeconstructiondesc                   None                       None
#
#                                             77576                      77577  \
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                         NaN                       2.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                          None                    Central
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                             77578                      77579
# typeconstructiontypeid                        NaN                        NaN
# storytypeid                                   NaN                        NaN
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                       7.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                 Floor/Wall
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
# [69 rows x 77580 columns]

# %% [markdown]
# **Handle missing values**
#
# Remove rows that are 75% emply and columns taht are 50% empty

# %%
def handle_missing_values(df, prop_required_column = .5, prop_required_row = .75, col_drop = []):
    # round the required columns times the length of the data frame to 0
    # remove every column that is 50% empty
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)

    # round the required rows times the length of the data frame to 0
    # remove every row that is 75% empty
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    
    # drop more specific columns
    df = df.drop(columns=col_drop)
    return df

# %%
# columns to drop
col_drop= ["propertylandusetypeid",
          "heatingorsystemtypeid",
           "buildingqualitytypeid",
           "calculatedfinishedsquarefeet",
           "calculatedbathnbr",
           ""
          "id",
           "heatingorsystemdesc",
           "propertyzoningdesc",
           "transactiondate"
          ]

zillow = handle_missing_values(df = zillow, col_drop = col_drop)
zillow.head()
# Out:
#    parcelid          bathroomcnt           bedroomcnt  finishedsquarefeet12  \
# 0  14297519                 3.50                 4.00              3,100.00
# 1  17052889                 1.00                 2.00              1,465.00
# 2  14186244                 2.00                 3.00              1,243.00
# 3  12177905                 3.00                 4.00              2,376.00
# 4  10887214                 3.00                 3.00              1,312.00
#
#                   fips          fullbathcnt             latitude  \
# 0             6,059.00                 3.00        33,634,931.00
# 1             6,111.00                 1.00        34,449,266.00
# 2             6,059.00                 2.00        33,886,168.00
# 3             6,037.00                 3.00        34,245,180.00
# 4             6,037.00                 3.00        34,185,120.00
#
#              longitude    lotsizesquarefeet propertycountylandusecode  ...  \
# 0      -117,869,207.00             4,506.00                       122  ...
# 1      -119,281,531.00            12,647.00                      1110  ...
# 2      -117,823,170.00             8,432.00                       122  ...
# 3      -118,240,722.00            13,038.00                      0101  ...
# 4      -118,414,640.00           278,581.00                      010C  ...
#
#              yearbuilt  structuretaxvaluedollarcnt    taxvaluedollarcnt  \
# 0             1,998.00                  485,713.00         1,023,282.00
# 1             1,967.00                   88,000.00           464,000.00
# 2             1,962.00                   85,289.00           564,778.00
# 3             1,970.00                  108,918.00           145,143.00
# 4             1,964.00                   73,681.00           119,407.00
#
#         assessmentyear  landtaxvaluedollarcnt            taxamount  \
# 0             2,016.00             537,569.00            11,013.72
# 1             2,016.00             376,000.00             5,672.48
# 2             2,016.00             479,489.00             6,488.30
# 3             2,016.00              36,225.00             1,777.51
# 4             2,016.00              45,726.00             1,533.89
#
#     censustractandblock             logerror  transactiondate  \
# 0 60,590,630,072,012.00                 0.03       2017-01-01
# 1 61,110,010,023,006.00                 0.06       2017-01-01
# 2 60,590,218,022,012.00                 0.01       2017-01-01
# 3 60,373,001,001,006.00                -0.10       2017-01-01
# 4 60,371,236,012,000.00                 0.01       2017-01-01
#
#          propertylandusedesc
# 0  Single Family Residential
# 1  Single Family Residential
# 2  Single Family Residential
# 3  Single Family Residential
# 4                Condominium
#
# [5 rows x 26 columns]

# %% [markdown]
# **Rename columns**

# %%
# rename dataframe columns
zillow = zillow.rename(columns={
    "bedroomcnt":"bedrooms",
    "bathroomcnt":"bathrooms",
    "finishedsquarefeet12":"sqr_feet",
    "taxvaluedollarcnt":"tax_value",
    "yearbuilt":"year_built",
    "taxamount":"tax_amount",
    "fips":"county"
})

# %%
zillow.county.value_counts()
# Out:
# 6,037.00    50661
# 6,059.00    20531
# 6,111.00     6232
# Name: county, dtype: int64

# %% [markdown]
# **Remove duplicates**

# %%
zilow = zillow.drop_duplicates(subset="parcelid", keep="first")

# %%
zillow.county.value_counts()
# Out:
# 6,037.00    50661
# 6,059.00    20531
# 6,111.00     6232
# Name: county, dtype: int64

# %% [markdown]
# **Fill null**

# %%
# Find all the columns that contains null values
cols = zillow.columns

for ele in cols:
    null_count = zillow[ele].isna().sum()
    
    # numeric columns
    if (null_count != 0) and (zillow[ele].dtypes != "O"):
        # fill nulls with median
        zillow[ele] = zillow[ele].fillna(zillow[ele].median())
        
#     elif null_count != 0:
#         # remove all nulls for object data types
#         zillow[ele] = zillow[ele].fillna("This is null")

# %%
# zillow = zillow[zillow.heatingorsystemdesc != "This is null"]
# # zillow = zillow[zillow.propertyzoningdesc != "This is null"]

# %% [markdown]
# **convert data type**

# %%
numeric_cols_to_covert = zillow.select_dtypes("float").drop(columns=["rawcensustractandblock","tax_amount","logerror", 
                                                           "tax_value","landtaxvaluedollarcnt","structuretaxvaluedollarcnt"]).columns
# convert data type from float to int
for i in numeric_cols_to_covert:
    zillow[i] = zillow[i].astype(int)

# %% [markdown]
# **Remove outliers**
#
# This is done using box plot in the explore phase. only looking at the training data.
#
# The IQR is major for determining outliers.

# %%
# add a new column to the data frame that indicates the outliers in the numeric columns.
def get_upper_outliers(s, k):
    '''
    Given a series and a cutoff value, k, returns the upper outliers for the
    series.

    The values returned will be either 0 (if the point is not an outlier), or a
    number that indicates how far away from the upper bound the observation is.
    '''
    q1, q3 = s.quantile([.25, .75])
    iqr = q3 - q1
    upper_bound = q3 + k * iqr
    return s.apply(lambda x: max([x - upper_bound, 0]))

# %%
def add_upper_outlier_columns(df, k):
    '''
    Add a column with the suffix _outliers for all the numeric columns
    in the given dataframe.
    '''
    # outlier_cols = {col + '_outliers': get_upper_outliers(df[col], k)
    #                 for col in df.select_dtypes('number')}
    # return df.assign(**outlier_cols)

    for col in df.select_dtypes('number'):
        df[col + '_outliers'] = get_upper_outliers(df[col], k)

    return df

# %%
zillow_outliers = add_upper_outlier_columns(zillow.copy(), k=1.5)
zillow_outliers
# Out:
#        parcelid  bathrooms  bedrooms  sqr_feet  county  fullbathcnt  latitude  \
# 0      14297519          3         4      3100    6059            3  33634931
# 1      17052889          1         2      1465    6111            1  34449266
# 2      14186244          2         3      1243    6059            2  33886168
# 3      12177905          3         4      2376    6037            3  34245180
# 4      10887214          3         3      1312    6037            3  34185120
# ...         ...        ...       ...       ...     ...          ...       ...
# 77575  11000655          2         2      1286    6037            2  34245368
# 77576  17239384          2         4      1612    6111            2  34300140
# 77577  12773139          1         3      1032    6037            1  34040895
# 77578  12826780          2         3      1762    6037            2  33937685
# 77579  13083743          2         3      1050    6037            2  34010864
#
#        longitude  lotsizesquarefeet propertycountylandusecode  ...  \
# 0     -117869207               4506                       122  ...
# 1     -119281531              12647                      1110  ...
# 2     -117823170               8432                       122  ...
# 3     -118240722              13038                      0101  ...
# 4     -118414640             278581                      010C  ...
# ...          ...                ...                       ...  ...
# 77575 -118282383              47405                      0100  ...
# 77576 -118706327              12105                      1111  ...
# 77577 -118038169               5074                      0100  ...
# 77578 -117996709               6347                      0100  ...
# 77579 -117900894               5927                      0100  ...
#
#           roomcnt_outliers     unitcnt_outliers  year_built_outliers  \
# 0                     0.00                 0.00                    0
# 1                     5.00                 0.00                    0
# 2                     6.00                 0.00                    0
# 3                     0.00                 0.00                    0
# 4                     0.00                 0.00                    0
# ...                    ...                  ...                  ...
# 77575                 0.00                 0.00                    0
# 77576                 7.00                 0.00                    0
# 77577                 0.00                 0.00                    0
# 77578                 0.00                 0.00                    0
# 77579                 0.00                 0.00                    0
#
#        structuretaxvaluedollarcnt_outliers   tax_value_outliers  \
# 0                                66,283.50                 0.00
# 1                                     0.00                 0.00
# 2                                     0.00                 0.00
# 3                                     0.00                 0.00
# 4                                     0.00                 0.00
# ...                                    ...                  ...
# 77575                                 0.00                 0.00
# 77576                                 0.00                 0.00
# 77577                                 0.00                 0.00
# 77578                                 0.00                 0.00
# 77579                                 0.00                 0.00
#
#        assessmentyear_outliers  landtaxvaluedollarcnt_outliers  \
# 0                         0.00                            0.00
# 1                         0.00                            0.00
# 2                         0.00                            0.00
# 3                         0.00                            0.00
# 4                         0.00                            0.00
# ...                        ...                             ...
# 77575                     0.00                            0.00
# 77576                     0.00                            0.00
# 77577                     0.00                            0.00
# 77578                     0.00                            0.00
# 77579                     0.00                            0.00
#
#        tax_amount_outliers  censustractandblock_outliers    logerror_outliers
# 0                     0.00                          0.00                 0.00
# 1                     0.00            193,616,944,991.12                 0.00
# 2                     0.00                          0.00                 0.00
# 3                     0.00                          0.00                 0.00
# 4                     0.00                          0.00                 0.00
# ...                    ...                           ...                  ...
# 77575                 0.00                          0.00                 0.00
# 77576                 0.00            193,690,944,001.12                 0.00
# 77577                 0.00                          0.00                 0.00
# 77578                 0.00                          0.00                 0.00
# 77579                 0.00                          0.00                 0.00
#
# [77424 rows x 49 columns]

# %%
# see what the outliers in our data look like:
outlier_cols = [col for col in zillow_outliers if col.endswith('_outliers')]
for col in outlier_cols:
    print('~~~\n' + col)
    data = zillow_outliers[col][zillow_outliers[col] > 0]
    print(data.describe())
# Out:
# ~~~
# parcelid_outliers
# count                  28.00
# mean          142,799,832.16
# std            21,178,645.24
# min            61,423,483.62
# 25%           148,250,263.12
# 50%           149,419,720.12
# 75%           149,420,309.12
# max           149,471,525.62
# Name: parcelid_outliers, dtype: float64
# ~~~
# bathrooms_outliers
# count               1,992.00
# mean                    1.11
# std                     1.03
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                    13.50
# Name: bathrooms_outliers, dtype: float64
# ~~~
# bedrooms_outliers
# count                 383.00
# mean                    1.64
# std                     1.17
# min                     1.00
# 25%                     1.00
# 50%                     1.00
# 75%                     2.00
# max                     9.00
# Name: bedrooms_outliers, dtype: float64
# ~~~
# sqr_feet_outliers
# count               4,468.00
# mean                1,042.25
# std                 1,314.27
# min                     1.00
# 25%                   249.00
# 50%                   621.00
# 75%                 1,338.00
# max                18,621.00
# Name: sqr_feet_outliers, dtype: float64
# ~~~
# county_outliers
# count               6,232.00
# mean                   19.00
# std                     0.00
# min                    19.00
# 25%                    19.00
# 50%                    19.00
# 75%                    19.00
# max                    19.00
# Name: county_outliers, dtype: float64
# ~~~
# fullbathcnt_outliers
# count               1,969.00
# mean                    1.11
# std                     1.03
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                    13.50
# Name: fullbathcnt_outliers, dtype: float64
# ~~~
# latitude_outliers
# count                 113.00
# mean               22,989.20
# std                28,621.97
# min                   395.25
# 25%                 2,825.25
# 50%                 4,720.25
# 75%                40,483.25
# max               105,241.25
# Name: latitude_outliers, dtype: float64
# ~~~
# longitude_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: longitude_outliers, dtype: float64
# ~~~
# lotsizesquarefeet_outliers
# count              13,164.00
# mean              110,114.23
# std               260,445.64
# min                     0.88
# 25%                 9,416.88
# 50%                34,904.88
# 75%               117,764.12
# max             6,953,642.88
# Name: lotsizesquarefeet_outliers, dtype: float64
# ~~~
# rawcensustractandblock_outliers
# count               6,232.00
# mean              193,656.59
# std                    24.29
# min               193,605.90
# 25%               193,639.95
# 50%               193,659.90
# 75%               193,678.97
# max               193,694.90
# Name: rawcensustractandblock_outliers, dtype: float64
# ~~~
# regionidcity_outliers
# count               2,142.00
# mean              162,560.03
# std               138,511.32
# min                18,587.50
# 25%                23,869.50
# 50%               177,753.50
# 75%               301,229.50
# max               301,731.50
# Name: regionidcity_outliers, dtype: float64
# ~~~
# regionidcounty_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: regionidcounty_outliers, dtype: float64
# ~~~
# regionidzip_outliers
# count                  12.00
# mean              301,499.50
# std                     0.00
# min               301,499.50
# 25%               301,499.50
# 50%               301,499.50
# 75%               301,499.50
# max               301,499.50
# Name: regionidzip_outliers, dtype: float64
# ~~~
# roomcnt_outliers
# count              17,611.00
# mean                    6.50
# std                     1.56
# min                     1.00
# 25%                     5.00
# 50%                     6.00
# 75%                     8.00
# max                    15.00
# Name: roomcnt_outliers, dtype: float64
# ~~~
# unitcnt_outliers
# count               3,290.00
# mean                    1.70
# std                     4.29
# min                     1.00
# 25%                     1.00
# 50%                     1.00
# 75%                     2.00
# max                   236.00
# Name: unitcnt_outliers, dtype: float64
# ~~~
# year_built_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: year_built_outliers, dtype: float64
# ~~~
# structuretaxvaluedollarcnt_outliers
# count               5,364.00
# mean              329,885.14
# std               554,618.61
# min                    95.50
# 25%                60,292.00
# 50%               165,867.00
# 75%               386,511.00
# max            11,002,360.50
# Name: structuretaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# tax_value_outliers
# count               5,153.00
# mean              948,448.91
# std             1,714,252.41
# min                   206.75
# 25%               174,289.75
# 50%               460,818.75
# 75%             1,071,295.75
# max            47,949,744.75
# Name: tax_value_outliers, dtype: float64
# ~~~
# assessmentyear_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: assessmentyear_outliers, dtype: float64
# ~~~
# landtaxvaluedollarcnt_outliers
# count               4,517.00
# mean              723,286.69
# std             1,442,836.86
# min                    59.88
# 25%               125,598.88
# 50%               339,207.88
# 75%               795,525.88
# max            48,163,723.88
# Name: landtaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# tax_amount_outliers
# count               5,190.00
# mean               10,898.40
# std                19,995.60
# min                     1.43
# 25%                 2,004.34
# 50%                 5,342.86
# 75%                12,194.53
# max               573,400.70
# Name: tax_amount_outliers, dtype: float64
# ~~~
# censustractandblock_outliers
# count                 6,215.00
# mean        261,547,063,039.44
# std       5,351,919,837,397.03
# min         193,608,923,031.12
# 25%         193,643,002,998.12
# 50%         193,662,925,031.12
# 75%         193,681,994,986.62
# max     422,113,712,006,000.12
# Name: censustractandblock_outliers, dtype: float64
# ~~~
# logerror_outliers
# count               5,391.00
# mean                    0.23
# std                     0.39
# min                     0.00
# 25%                     0.04
# 50%                     0.10
# 75%                     0.24
# max                     5.13
# Name: logerror_outliers, dtype: float64

# %%
# remove outliers
zillow = zillow[zillow.bedrooms < 5]
zillow = zillow[zillow.bathrooms < 5]
zillow = zillow[(zillow.year_built >= 1910) & (zillow.year_built <= 2017)]
zillow = zillow[(zillow.sqr_feet > 500) & (zillow.sqr_feet <= 3800)]
zillow = zillow[zillow.tax_amount <= 20000]
zillow = zillow[zillow.tax_value <= 1_000_000]

# %% [markdown]
# **feature engineeing**

# %%
# Rename the unique values in fips to county names
zillow.county = zillow.county.astype(str).str.replace("6037","Los Angeles").str.replace("6059","Orange").str.replace("6111","Sam Juan")

# %% [markdown]
# ## Split

# %%
# split the data into training, validation and testing sets
train, validate, test = prepare_.split_data_(df=zillow,
                    test_size=0.2, 
                     validate_size=0.2, 
                     random_state=95)
(train.shape, validate.shape, test.shape)
# Out:
# ((39405, 26), (13135, 26), (13136, 26))

# %% [markdown]
# **Save split**

# %%
prepare_.save_split_data(encoded_df=zillow, train=train, validate=validate, test=test)
# Out:
# 'Four data sets saved as .csv'
