# %% [markdown]
# # Acquire
#
# **Goal: Your goal is to predict the values of single unit properties using the obervations from 2017.**
#
# **import**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
from sklearn.model_selection import train_test_split

sys.path.append("./util_")
import acquire_
import prepare_

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **get data**

# %%
# sql query
query = """
SELECT *
FROM properties_2017 AS prop
INNER JOIN predictions_2017 USING(parcelid)
LEFT JOIN airconditioningtype USING(airconditioningtypeid)
LEFT JOIN architecturalstyletype USING(architecturalstyletypeid)
LEFT JOIN buildingclasstype USING(buildingclasstypeid)
LEFT JOIN heatingorsystemtype USING(heatingorsystemtypeid)
LEFT JOIN propertylandusetype USING(propertylandusetypeid)
LEFT JOIN storytype USING(storytypeid)
LEFT JOIN typeconstructiontype USING(typeconstructiontypeid)
WHERE prop.unitcnt = 1;
"""

# %%
# get data from codeup database
zillow, q = acquire_.get_codeup_sql_data_(db_name="zillow", query=query,fileName="zillow_single_family")

# %% [markdown]
# ## Understand data

# %%
zillow.shape
# Out:
# (47414, 69)

# %%
zillow.columns
# Out:
# Index(['typeconstructiontypeid', 'storytypeid', 'propertylandusetypeid',
#        'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'parcelid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'id', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %%
zillow.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47414 entries, 0 to 47413
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        0 non-null      object
#  1   storytypeid                   0 non-null      object
#  2   propertylandusetypeid         47414 non-null  float64
#  3   heatingorsystemtypeid         46685 non-null  float64
#  4   buildingclasstypeid           8 non-null      float64
#  5   architecturalstyletypeid      0 non-null      object
#  6   airconditioningtypeid         22070 non-null  float64
#  7   parcelid                      47414 non-null  int64
#  8   id                            47414 non-null  int64
#  9   basementsqft                  0 non-null      object
#  10  bathroomcnt                   47414 non-null  float64
#  11  bedroomcnt                    47414 non-null  float64
#  12  buildingqualitytypeid         46923 non-null  float64
#  13  calculatedbathnbr             47368 non-null  float64
#  14  decktypeid                    0 non-null      object
#  15  finishedfloor1squarefeet      0 non-null      object
#  16  calculatedfinishedsquarefeet  47407 non-null  float64
#  17  finishedsquarefeet12          47366 non-null  float64
#  18  finishedsquarefeet13          0 non-null      object
#  19  finishedsquarefeet15          36 non-null     float64
#  20  finishedsquarefeet50          0 non-null      object
#  21  finishedsquarefeet6           5 non-null      float64
#  22  fips                          47414 non-null  float64
#  23  fireplacecnt                  0 non-null      object
#  24  fullbathcnt                   47368 non-null  float64
#  25  garagecarcnt                  10 non-null     float64
#  26  garagetotalsqft               10 non-null     float64
#  27  hashottuborspa                0 non-null      object
#  28  latitude                      47414 non-null  float64
#  29  longitude                     47414 non-null  float64
#  30  lotsizesquarefeet             46179 non-null  float64
#  31  poolcnt                       11603 non-null  float64
#  32  poolsizesum                   0 non-null      object
#  33  pooltypeid10                  0 non-null      object
#  34  pooltypeid2                   0 non-null      object
#  35  pooltypeid7                   11582 non-null  float64
#  36  propertycountylandusecode     47414 non-null  object
#  37  propertyzoningdesc            47184 non-null  object
#  38  rawcensustractandblock        47414 non-null  float64
#  39  regionidcity                  46372 non-null  float64
#  40  regionidcounty                47414 non-null  float64
#  41  regionidneighborhood          24146 non-null  float64
#  42  regionidzip                   47394 non-null  float64
#  43  roomcnt                       47414 non-null  float64
#  44  threequarterbathnbr           0 non-null      object
#  45  unitcnt                       47414 non-null  float64
#  46  yardbuildingsqft17            0 non-null      object
#  47  yardbuildingsqft26            0 non-null      object
#  48  yearbuilt                     47400 non-null  float64
#  49  numberofstories               20 non-null     float64
#  50  fireplaceflag                 0 non-null      object
#  51  structuretaxvaluedollarcnt    47350 non-null  float64
#  52  taxvaluedollarcnt             47414 non-null  float64
#  53  assessmentyear                47414 non-null  float64
#  54  landtaxvaluedollarcnt         47414 non-null  float64
#  55  taxamount                     47410 non-null  float64
#  56  taxdelinquencyflag            2210 non-null   object
#  57  taxdelinquencyyear            2210 non-null   float64
#  58  censustractandblock           47298 non-null  float64
#  59  id                            47414 non-null  int64
#  60  logerror                      47414 non-null  float64
#  61  transactiondate               47414 non-null  object
#  62  airconditioningdesc           22070 non-null  object
#  63  architecturalstyledesc        0 non-null      object
#  64  buildingclassdesc             8 non-null      object
#  65  heatingorsystemdesc           46685 non-null  object
#  66  propertylandusedesc           47414 non-null  object
#  67  storydesc                     0 non-null      object
#  68  typeconstructiondesc          0 non-null      object
# dtypes: float64(38), int64(3), object(28)
# memory usage: 25.0+ MB

# %%
zillow.describe()
# Out:
#        propertylandusetypeid  heatingorsystemtypeid  buildingclasstypeid  \
# count              47,414.00              46,685.00                 8.00
# mean                  262.50                   3.46                 3.88
# std                     3.94                   2.39                 0.35
# min                    31.00                   2.00                 3.00
# 25%                   261.00                   2.00                 4.00
# 50%                   261.00                   2.00                 4.00
# 75%                   266.00                   7.00                 4.00
# max                   269.00                  20.00                 4.00
#
#        airconditioningtypeid             parcelid                   id  \
# count              22,070.00            47,414.00            47,414.00
# mean                    1.00        11,914,053.44         1,498,375.90
# std                     0.00         3,279,810.25           860,854.17
# min                     1.00        10,711,855.00             1,307.00
# 25%                     1.00        11,178,074.00           760,320.75
# 50%                     1.00        11,819,691.50         1,501,084.00
# 75%                     1.00        12,511,668.75         2,245,365.75
# max                     1.00       167,688,532.00         2,982,188.00
#
#                bathroomcnt           bedroomcnt  buildingqualitytypeid  \
# count            47,414.00            47,414.00              46,923.00
# mean                  2.24                 2.95                   6.63
# std                   0.99                 1.01                   1.69
# min                   0.00                 0.00                   1.00
# 25%                   2.00                 2.00                   6.00
# 50%                   2.00                 3.00                   7.00
# 75%                   3.00                 4.00                   8.00
# max                  13.00                11.00                  12.00
#
#          calculatedbathnbr  ...      numberofstories  \
# count            47,368.00  ...                20.00
# mean                  2.24  ...                 1.35
# std                   0.99  ...                 0.59
# min                   1.00  ...                 1.00
# 25%                   2.00  ...                 1.00
# 50%                   2.00  ...                 1.00
# 75%                   3.00  ...                 2.00
# max                  13.00  ...                 3.00
#
#        structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# count                   47,350.00            47,414.00            47,414.00
# mean                   187,052.90           473,141.27             2,016.00
# std                    240,719.11           688,181.63                 0.00
# min                        129.00             1,000.00             2,016.00
# 25%                     83,785.00           184,850.75             2,016.00
# 50%                    134,077.50           328,229.50             2,016.00
# 75%                    212,207.00           533,298.00             2,016.00
# max                  9,164,901.00        25,381,250.00             2,016.00
#
#        landtaxvaluedollarcnt            taxamount   taxdelinquencyyear  \
# count              47,414.00            47,410.00             2,210.00
# mean              286,340.85             5,955.53                14.11
# std               503,762.33             8,114.74                 2.34
# min                   161.00               120.84                 4.00
# 25%                64,802.00             2,567.36                14.00
# 50%               176,778.50             4,263.53                15.00
# 75%               336,808.25             6,670.62                15.00
# max            22,335,500.00           290,998.06                99.00
#
#          censustractandblock                   id             logerror
# count              47,298.00            47,414.00            47,414.00
# mean   60,383,594,664,841.11            38,900.23                 0.01
# std     1,943,422,866,929.52            22,573.53                 0.16
# min    60,371,011,101,000.00                 3.00                -4.66
# 25%    60,372,351,002,010.00            19,292.25                -0.03
# 50%    60,374,315,013,001.50            38,818.50                 0.01
# 75%    60,376,023,024,017.00            58,362.50                 0.04
# max   483,030,105,084,015.00            77,613.00                 5.26
#
# [8 rows x 41 columns]

# %%
# count of numeric columns and object columns
numerics = len(zillow.select_dtypes("number").columns)
objects = len(zillow.select_dtypes("object").columns)

print("Numeric col count:", numerics)
print("object col count:", objects)
# Out:
# Numeric col count: 41
# object col count: 28

# %% [markdown]
# Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
# create a dataframe from all the null counts
zillow_null_status = pd.DataFrame(zillow.isna().sum(axis=0))
zillow_null_status = zillow_null_status.rename(columns={0:"num_rows_missing"})

# add percentage of th missing values to the new data frame
zillow_null_status["pct_rows_missing"] = zillow_null_status.num_rows_missing / zillow.shape[0]
zillow_null_status.head()
# Out:
#                         num_rows_missing     pct_rows_missing
# typeconstructiontypeid             47414                 1.00
# storytypeid                        47414                 1.00
# propertylandusetypeid                  0                 0.00
# heatingorsystemtypeid                729                 0.02
# buildingclasstypeid                47406                 1.00

# %% [markdown]
# **What I see:**
#
# - I have 2152863 rows and 7 columns
# - 7 of the 29 columns are numric while 0 of them are string object colums
# - I have unsure null values in my data
# - I also see the descriptive statistics of my data

# %% [markdown]
# # Prepare

# %%
zillow.T
# Out:
#                                             0                    1      \
# typeconstructiontypeid                       None                 None
# storytypeid                                  None                 None
# propertylandusetypeid                      261.00               266.00
# heatingorsystemtypeid                        2.00                 2.00
# buildingclasstypeid                           NaN                  NaN
# ...                                           ...                  ...
# buildingclassdesc                            None                 None
# heatingorsystemdesc                       Central              Central
# propertylandusedesc     Single Family Residential          Condominium
# storydesc                                    None                 None
# typeconstructiondesc                         None                 None
#
#                                             2                          3      \
# typeconstructiontypeid                       None                       None
# storytypeid                                  None                       None
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                        NaN
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                       None
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                             4                    5      \
# typeconstructiontypeid                       None                 None
# storytypeid                                  None                 None
# propertylandusetypeid                      261.00               266.00
# heatingorsystemtypeid                        2.00                 2.00
# buildingclasstypeid                           NaN                  NaN
# ...                                           ...                  ...
# buildingclassdesc                            None                 None
# heatingorsystemdesc                       Central              Central
# propertylandusedesc     Single Family Residential          Condominium
# storydesc                                    None                 None
# typeconstructiondesc                         None                 None
#
#                                             6                    7      \
# typeconstructiontypeid                       None                 None
# storytypeid                                  None                 None
# propertylandusetypeid                      261.00               266.00
# heatingorsystemtypeid                        2.00                 2.00
# buildingclasstypeid                           NaN                  NaN
# ...                                           ...                  ...
# buildingclassdesc                            None                 None
# heatingorsystemdesc                       Central              Central
# propertylandusedesc     Single Family Residential          Condominium
# storydesc                                    None                 None
# typeconstructiondesc                         None                 None
#
#                                             8                    9      ...  \
# typeconstructiontypeid                       None                 None  ...
# storytypeid                                  None                 None  ...
# propertylandusetypeid                      261.00               266.00  ...
# heatingorsystemtypeid                        7.00                 2.00  ...
# buildingclasstypeid                           NaN                  NaN  ...
# ...                                           ...                  ...  ...
# buildingclassdesc                            None                 None  ...
# heatingorsystemdesc                    Floor/Wall              Central  ...
# propertylandusedesc     Single Family Residential          Condominium  ...
# storydesc                                    None                 None  ...
# typeconstructiondesc                         None                 None  ...
#
#                                             47404                47405  \
# typeconstructiontypeid                       None                 None
# storytypeid                                  None                 None
# propertylandusetypeid                      261.00               266.00
# heatingorsystemtypeid                        2.00                 2.00
# buildingclasstypeid                           NaN                  NaN
# ...                                           ...                  ...
# buildingclassdesc                            None                 None
# heatingorsystemdesc                       Central              Central
# propertylandusedesc     Single Family Residential          Condominium
# storydesc                                    None                 None
# typeconstructiondesc                         None                 None
#
#                                       47406                      47407  \
# typeconstructiontypeid                 None                       None
# storytypeid                            None                       None
# propertylandusetypeid                266.00                     261.00
# heatingorsystemtypeid                  2.00                       2.00
# buildingclasstypeid                     NaN                        NaN
# ...                                     ...                        ...
# buildingclassdesc                      None                       None
# heatingorsystemdesc                 Central                    Central
# propertylandusedesc             Condominium  Single Family Residential
# storydesc                              None                       None
# typeconstructiondesc                   None                       None
#
#                                             47408                47409  \
# typeconstructiontypeid                       None                 None
# storytypeid                                  None                 None
# propertylandusetypeid                      261.00               266.00
# heatingorsystemtypeid                        2.00                 2.00
# buildingclasstypeid                           NaN                  NaN
# ...                                           ...                  ...
# buildingclassdesc                            None                 None
# heatingorsystemdesc                       Central              Central
# propertylandusedesc     Single Family Residential          Condominium
# storydesc                                    None                 None
# typeconstructiondesc                         None                 None
#
#                                             47410                      47411  \
# typeconstructiontypeid                       None                       None
# storytypeid                                  None                       None
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                       2.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                    Central
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
#                                             47412                      47413
# typeconstructiontypeid                       None                       None
# storytypeid                                  None                       None
# propertylandusetypeid                      261.00                     261.00
# heatingorsystemtypeid                        2.00                       7.00
# buildingclasstypeid                           NaN                        NaN
# ...                                           ...                        ...
# buildingclassdesc                            None                       None
# heatingorsystemdesc                       Central                 Floor/Wall
# propertylandusedesc     Single Family Residential  Single Family Residential
# storydesc                                    None                       None
# typeconstructiondesc                         None                       None
#
# [69 rows x 47414 columns]

# %% [markdown]
# **Handle missing values**
#
# Remove rows that are 75% emply and columns taht are 50% empty

# %%
def handle_missing_values(df, prop_required_column = .5, prop_required_row = .75, col_drop = []):
    # round the required columns times the length of the data frame to 0
    # remove every column that is 50% empty
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)

    # round the required rows times the length of the data frame to 0
    # remove every row that is 75% empty
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    
    # drop more specific columns
    df = df.drop(columns=col_drop)
    return df

# %%
# columns to drop
col_drop= ["propertylandusetypeid",
          "heatingorsystemtypeid",
           "buildingqualitytypeid",
           "calculatedfinishedsquarefeet",
           "calculatedbathnbr",
           ""
          "id"
          ]

zillow = handle_missing_values(df = zillow, col_drop = col_drop)
zillow.head()
# Out:
#    parcelid          bathroomcnt           bedroomcnt  finishedsquarefeet12  \
# 0  12177905                 3.00                 4.00              2,376.00
# 1  10887214                 3.00                 3.00              1,312.00
# 2  12095076                 3.00                 4.00              2,962.00
# 3  12069064                 1.00                 2.00                738.00
# 4  12790562                 3.00                 4.00              3,039.00
#
#                   fips          fullbathcnt             latitude  \
# 0             6,037.00                 3.00        34,245,180.00
# 1             6,037.00                 3.00        34,185,120.00
# 2             6,037.00                 3.00        34,145,202.00
# 3             6,037.00                 1.00        34,149,214.00
# 4             6,037.00                 3.00        33,960,230.00
#
#              longitude    lotsizesquarefeet propertycountylandusecode  ...  \
# 0      -118,240,722.00            13,038.00                      0101  ...
# 1      -118,414,640.00           278,581.00                      010C  ...
# 2      -118,179,824.00            63,000.00                      0101  ...
# 3      -118,239,357.00             4,214.00                      0100  ...
# 4      -118,006,914.00            20,028.00                      0100  ...
#
#   structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# 0                 108,918.00           145,143.00             2,016.00
# 1                  73,681.00           119,407.00             2,016.00
# 2                 276,684.00           773,303.00             2,016.00
# 3                  18,890.00           218,552.00             2,016.00
# 4                 177,527.00           220,583.00             2,016.00
#
#    landtaxvaluedollarcnt            taxamount   censustractandblock  \
# 0              36,225.00             1,777.51 60,373,001,001,006.00
# 1              45,726.00             1,533.89 60,371,236,012,000.00
# 2             496,619.00             9,516.26 60,374,608,001,014.00
# 3             199,662.00             2,366.08 60,373,020,041,001.00
# 4              43,056.00             3,104.19 60,375,002,024,006.00
#
#               logerror  transactiondate  heatingorsystemdesc  \
# 0                -0.10       2017-01-01              Central
# 1                 0.01       2017-01-01              Central
# 2                -0.00       2017-01-01              Central
# 3                 0.10       2017-01-01                 None
# 4                -0.04       2017-01-02              Central
#
#          propertylandusedesc
# 0  Single Family Residential
# 1                Condominium
# 2  Single Family Residential
# 3  Single Family Residential
# 4  Single Family Residential
#
# [5 rows x 29 columns]

# %% [markdown]
# **Rename columns**

# %%
# rename dataframe columns
zillow = zillow.rename(columns={
    "bedroomcnt":"bedrooms",
    "bathroomcnt":"bathrooms",
    "calculatedfinishedsquarefeet":"sqr_feet",
    "taxvaluedollarcnt":"tax_value",
    "yearbuilt":"year_built",
    "taxamount":"tax_amount",
    "fips":"county"
})

# %% [markdown]
# **convert data type**

# %%
# zillow.select_dtypes("float").drop(columns=["rawcensustractandblock","tax_amount","logerror", "tax_value","landtaxvaluedollarcnt","structuretaxvaluedollarcnt"])

# %%
# # convert data type from float to int
# zillow.bedrooms = zillow.bedrooms.astype(int)
# zillow.year_built = zillow.year_built.astype(int)

# %% [markdown]
# **Remove outliers**
#
# This is done using box plot in the explore phase. only looking at the training data.
#
# The IQR is major for determining outliers.

# %%
# add a new column to the data frame that indicates the outliers in the numeric columns.
def get_upper_outliers(s, k):
    '''
    Given a series and a cutoff value, k, returns the upper outliers for the
    series.

    The values returned will be either 0 (if the point is not an outlier), or a
    number that indicates how far away from the upper bound the observation is.
    '''
    q1, q3 = s.quantile([.25, .75])
    iqr = q3 - q1
    upper_bound = q3 + k * iqr
    return s.apply(lambda x: max([x - upper_bound, 0]))

def add_upper_outlier_columns(df, k):
    '''
    Add a column with the suffix _outliers for all the numeric columns
    in the given dataframe.
    '''
    # outlier_cols = {col + '_outliers': get_upper_outliers(df[col], k)
    #                 for col in df.select_dtypes('number')}
    # return df.assign(**outlier_cols)

    for col in df.select_dtypes('number'):
        df[col + '_outliers'] = get_upper_outliers(df[col], k)

    return df

zillow_outliers = add_upper_outlier_columns(zillow, k=1.5)
zillow_outliers
# Out:
#        parcelid            bathrooms             bedrooms  \
# 0      12177905                 3.00                 4.00
# 1      10887214                 3.00                 3.00
# 2      12095076                 3.00                 4.00
# 3      12069064                 1.00                 2.00
# 4      12790562                 3.00                 4.00
# ...         ...                  ...                  ...
# 47409  10833991                 3.00                 3.00
# 47410  11000655                 2.00                 2.00
# 47411  12773139                 1.00                 3.00
# 47412  12826780                 2.00                 3.00
# 47413  13083743                 2.00                 3.00
#
#        finishedsquarefeet12               county          fullbathcnt  \
# 0                  2,376.00             6,037.00                 3.00
# 1                  1,312.00             6,037.00                 3.00
# 2                  2,962.00             6,037.00                 3.00
# 3                    738.00             6,037.00                 1.00
# 4                  3,039.00             6,037.00                 3.00
# ...                     ...                  ...                  ...
# 47409              1,741.00             6,037.00                 3.00
# 47410              1,286.00             6,037.00                 2.00
# 47411              1,032.00             6,037.00                 1.00
# 47412              1,762.00             6,037.00                 2.00
# 47413              1,050.00             6,037.00                 2.00
#
#                   latitude            longitude    lotsizesquarefeet  \
# 0            34,245,180.00      -118,240,722.00            13,038.00
# 1            34,185,120.00      -118,414,640.00           278,581.00
# 2            34,145,202.00      -118,179,824.00            63,000.00
# 3            34,149,214.00      -118,239,357.00             4,214.00
# 4            33,960,230.00      -118,006,914.00            20,028.00
# ...                    ...                  ...                  ...
# 47409        34,202,400.00      -118,502,000.00            59,487.00
# 47410        34,245,368.00      -118,282,383.00            47,405.00
# 47411        34,040,895.00      -118,038,169.00             5,074.00
# 47412        33,937,685.00      -117,996,709.00             6,347.00
# 47413        34,010,864.00      -117,900,894.00             5,927.00
#
#       propertycountylandusecode  ...     roomcnt_outliers  \
# 0                          0101  ...                 0.00
# 1                          010C  ...                 0.00
# 2                          0101  ...                 0.00
# 3                          0100  ...                 0.00
# 4                          0100  ...                 0.00
# ...                         ...  ...                  ...
# 47409                      010C  ...                 0.00
# 47410                      0100  ...                 0.00
# 47411                      0100  ...                 0.00
# 47412                      0100  ...                 0.00
# 47413                      0100  ...                 0.00
#
#           unitcnt_outliers  year_built_outliers  \
# 0                     0.00                 0.00
# 1                     0.00                 0.00
# 2                     0.00                 0.00
# 3                     0.00                 0.00
# 4                     0.00                 0.00
# ...                    ...                  ...
# 47409                 0.00                 0.00
# 47410                 0.00                 0.00
# 47411                 0.00                 0.00
# 47412                 0.00                 0.00
# 47413                 0.00                 0.00
#
#        structuretaxvaluedollarcnt_outliers   tax_value_outliers  \
# 0                                     0.00                 0.00
# 1                                     0.00                 0.00
# 2                                     0.00                 0.00
# 3                                     0.00                 0.00
# 4                                     0.00                 0.00
# ...                                    ...                  ...
# 47409                                 0.00                 0.00
# 47410                                 0.00                 0.00
# 47411                                 0.00                 0.00
# 47412                                 0.00                 0.00
# 47413                                 0.00                 0.00
#
#        assessmentyear_outliers  landtaxvaluedollarcnt_outliers  \
# 0                         0.00                            0.00
# 1                         0.00                            0.00
# 2                         0.00                            0.00
# 3                         0.00                            0.00
# 4                         0.00                            0.00
# ...                        ...                             ...
# 47409                     0.00                            0.00
# 47410                     0.00                            0.00
# 47411                     0.00                            0.00
# 47412                     0.00                            0.00
# 47413                     0.00                            0.00
#
#        tax_amount_outliers  censustractandblock_outliers    logerror_outliers
# 0                     0.00                          0.00                 0.00
# 1                     0.00                          0.00                 0.00
# 2                     0.00                          0.00                 0.00
# 3                     0.00                          0.00                 0.00
# 4                     0.00                          0.00                 0.00
# ...                    ...                           ...                  ...
# 47409                 0.00                          0.00                 0.00
# 47410                 0.00                          0.00                 0.00
# 47411                 0.00                          0.00                 0.00
# 47412                 0.00                          0.00                 0.00
# 47413                 0.00                          0.00                 0.00
#
# [47414 rows x 53 columns]

# %%
# see what the outliers in our data look like:
outlier_cols = [col for col in zillow_outliers if col.endswith('_outliers')]
for col in outlier_cols:
    print('~~~\n' + col)
    data = zillow_outliers[col][zillow_outliers[col] > 0]
    print(data.describe())
# Out:
# ~~~
# parcelid_outliers
# count                  21.00
# mean          145,959,960.70
# std            32,850,903.88
# min             2,586,871.12
# 25%           153,124,435.12
# 50%           153,124,979.12
# 75%           153,125,942.12
# max           153,176,471.12
# Name: parcelid_outliers, dtype: float64
# ~~~
# bathrooms_outliers
# count               1,283.00
# mean                    1.07
# std                     0.97
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                     8.50
# Name: bathrooms_outliers, dtype: float64
# ~~~
# bedrooms_outliers
# count                  30.00
# mean                    1.47
# std                     0.78
# min                     1.00
# 25%                     1.00
# 50%                     1.00
# 75%                     2.00
# max                     4.00
# Name: bedrooms_outliers, dtype: float64
# ~~~
# finishedsquarefeet12_outliers
# count               2,740.00
# mean                1,088.66
# std                 1,430.85
# min                     0.50
# 25%                   238.25
# 50%                   631.00
# 75%                 1,361.50
# max                18,707.50
# Name: finishedsquarefeet12_outliers, dtype: float64
# ~~~
# county_outliers
# count                  11.00
# mean                   26.73
# std                    15.68
# min                    22.00
# 25%                    22.00
# 50%                    22.00
# 75%                    22.00
# max                    74.00
# Name: county_outliers, dtype: float64
# ~~~
# fullbathcnt_outliers
# count               1,283.00
# mean                    1.07
# std                     0.97
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                     8.50
# Name: fullbathcnt_outliers, dtype: float64
# ~~~
# latitude_outliers
# count               3,436.00
# mean               87,726.90
# std                54,364.04
# min                    18.50
# 25%                32,018.00
# 50%               101,237.50
# 75%               134,551.75
# max               268,752.50
# Name: latitude_outliers, dtype: float64
# ~~~
# longitude_outliers
# count                   1.00
# mean               39,455.88
# std                      NaN
# min                39,455.88
# 25%                39,455.88
# 50%                39,455.88
# 75%                39,455.88
# max                39,455.88
# Name: longitude_outliers, dtype: float64
# ~~~
# lotsizesquarefeet_outliers
# count               7,904.00
# mean              156,348.58
# std               317,680.17
# min                    19.75
# 25%                21,861.00
# 50%                68,417.75
# 75%               182,039.00
# max             6,935,178.75
# Name: lotsizesquarefeet_outliers, dtype: float64
# ~~~
# rawcensustractandblock_outliers
# count                  11.00
# mean              256,307.10
# std               156,597.60
# min               208,477.04
# 25%               209,086.50
# 50%               209,090.04
# 75%               209,328.98
# max               728,465.98
# Name: rawcensustractandblock_outliers, dtype: float64
# ~~~
# regionidcity_outliers
# count               1,972.00
# mean              158,078.54
# std               138,632.53
# min                18,077.50
# 25%                22,890.50
# 50%                23,659.50
# 75%               300,719.50
# max               301,221.50
# Name: regionidcity_outliers, dtype: float64
# ~~~
# regionidcounty_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: regionidcounty_outliers, dtype: float64
# ~~~
# regionidneighborhood_outliers
# count                 721.00
# mean              133,554.20
# std                 1,168.50
# min               128,209.50
# 25%               132,404.50
# 50%               133,542.50
# 75%               134,537.50
# max               135,024.50
# Name: regionidneighborhood_outliers, dtype: float64
# ~~~
# regionidzip_outliers
# count               3,735.00
# mean                1,419.05
# std                17,112.75
# min                    83.00
# 25%                   444.00
# 50%                   445.00
# 75%                   455.00
# max               302,801.00
# Name: regionidzip_outliers, dtype: float64
# ~~~
# roomcnt_outliers
# count                   4.00
# mean                    5.75
# std                     1.71
# min                     4.00
# 25%                     4.75
# 50%                     5.50
# 75%                     6.50
# max                     8.00
# Name: roomcnt_outliers, dtype: float64
# ~~~
# unitcnt_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: unitcnt_outliers, dtype: float64
# ~~~
# year_built_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: year_built_outliers, dtype: float64
# ~~~
# structuretaxvaluedollarcnt_outliers
# count               3,401.00
# mean              356,171.35
# std               599,288.30
# min                    46.00
# 25%                60,960.00
# 50%               167,483.00
# 75%               412,004.00
# max             8,760,061.00
# Name: structuretaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# tax_value_outliers
# count               3,447.00
# mean            1,017,285.06
# std             1,762,331.94
# min                   274.12
# 25%               184,089.12
# 50%               494,031.12
# 75%             1,135,519.12
# max            24,325,281.12
# Name: tax_value_outliers, dtype: float64
# ~~~
# assessmentyear_outliers
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: assessmentyear_outliers, dtype: float64
# ~~~
# landtaxvaluedollarcnt_outliers
# count               3,166.00
# mean              737,073.74
# std             1,371,689.34
# min                     3.38
# 25%               133,197.88
# 50%               343,458.88
# 75%               779,000.38
# max            21,590,682.38
# Name: landtaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# tax_amount_outliers
# count               3,480.00
# mean               11,846.58
# std                20,701.88
# min                     7.57
# 25%                 2,130.24
# 50%                 5,676.16
# 75%                13,205.82
# max               278,172.56
# Name: tax_amount_outliers, dtype: float64
# ~~~
# censustractandblock_outliers
# count                    19.00
# mean     22,488,990,432,299.66
# std      96,903,141,159,530.48
# min         208,486,005,977.50
# 25%         209,097,975,001.00
# 50%         209,333,954,972.50
# 75%         268,934,964,981.50
# max     422,648,574,026,987.50
# Name: censustractandblock_outliers, dtype: float64
# ~~~
# logerror_outliers
# count               3,200.00
# mean                    0.21
# std                     0.34
# min                     0.00
# 25%                     0.04
# 50%                     0.10
# 75%                     0.24
# max                     5.12
# Name: logerror_outliers, dtype: float64

# %%
# # remove outliers
# zillow = zillow[zillow.bedrooms <= 7]
# zillow = zillow[zillow.bathrooms <= 7]
# zillow = zillow[zillow.year_built >= 1900]
# zillow = zillow[zillow.sqr_feet <= 5000]
# zillow = zillow[zillow.tax_amount <= 20000]

# %% [markdown]
# **feature engineeing**

# %%
# Rename the unique values in fips to county names
zillow.county = zillow.county.astype(str).str.replace("6037.0","Los Angeles").str.replace("6059.0","Orange").str.replace("6111.0","Sam Juan")

# %% [markdown]
# ## Split

# %%
# split the data into training, validation and testing sets
train, validate, test = prepare_.split_data_(df=zillow,
                    test_size=0.2, 
                     validate_size=0.2, 
                     random_state=95)
(train.shape, validate.shape, test.shape)
# Out:
# ((28448, 53), (9483, 53), (9483, 53))

# %% [markdown]
# **Save split**

# %%
prepare_.save_split_data(encoded_df=zillow, train=train, validate=validate, test=test)
# Out:
# 'Four data sets saved as .csv'
